# %%
import pandas as pd

# %%
ls
# Out:
# Datensatzbeschreibung_Gitter100m_Familien.xlsx
# Familie100m.csv
# ~$Datensatzbeschreibung_Gitter100m_Familien.xlsx

# %%
path = '/Germany_Census_2011/csv_Familien_100m_Gitter'

# %%
families = pd.read_csv('Familie100m.csv', delimiter=',', encoding="cp1252")

# %%
families
# Out:
#             Gitter_ID_100m              Gitter_ID_100m_neu          Merkmal  \
# 0         100mN26912E43412  CRS3035RES100mN2691200E4341200        INSGESAMT
# 1         100mN26917E43411  CRS3035RES100mN2691700E4341100        INSGESAMT
# 2         100mN26917E43411  CRS3035RES100mN2691700E4341100  FAMGROESS_KLASS
# 3         100mN26917E43411  CRS3035RES100mN2691700E4341100  HHTYP_SENIOR_HH
# 4         100mN26924E43412  CRS3035RES100mN2692400E4341200        INSGESAMT
# ...                    ...                             ...              ...
# 14327260  100mN35476E42199  CRS3035RES100mN3547600E4219900  HHTYP_SENIOR_HH
# 14327261  100mN35476E42201  CRS3035RES100mN3547600E4220100        INSGESAMT
# 14327262  100mN35476E42201  CRS3035RES100mN3547600E4220100  FAMGROESS_KLASS
# 14327263  100mN35476E42201  CRS3035RES100mN3547600E4220100      FAMTYP_KIND
# 14327264  100mN35476E42201  CRS3035RES100mN3547600E4220100  HHTYP_SENIOR_HH
#
#           Auspraegung_Code                              Auspraegung_Text  \
# 0                        0                           Einheiten insgesamt
# 1                        0                           Einheiten insgesamt
# 2                        1                                    2 Personen
# 3                        2    Haushalte mit Senioren/-innen und Jüngeren
# 4                        0                           Einheiten insgesamt
# ...                    ...                                           ...
# 14327260                 3                Haushalte ohne Senioren/-innen
# 14327261                 0                           Einheiten insgesamt
# 14327262                 1                                    2 Personen
# 14327263                 1                            Ehepaare ohne Kind
# 14327264                 1  Haushalte mit ausschließlich Senioren/-innen
#
#           Anzahl  Anzahl_q
# 0              3         0
# 1              3         0
# 2              3         0
# 3              3         0
# 4              3         0
# ...          ...       ...
# 14327260       3         0
# 14327261       4         0
# 14327262       3         0
# 14327263       3         0
# 14327264       3         0
#
# [14327265 rows x 7 columns]

# %%
pivot_df = families.pivot(columns=['Merkmal', 'Auspraegung_Text'], values='Anzahl')

# %%
pivot_df
# Out:
# Merkmal                    INSGESAMT FAMGROESS_KLASS  \
# Auspraegung_Text Einheiten insgesamt      2 Personen
# 0                                3.0             NaN
# 1                                3.0             NaN
# 2                                NaN             3.0
# 3                                NaN             NaN
# 4                                3.0             NaN
# ...                              ...             ...
# 14327260                         NaN             NaN
# 14327261                         4.0             NaN
# 14327262                         NaN             3.0
# 14327263                         NaN             NaN
# 14327264                         NaN             NaN
#
# Merkmal                                     HHTYP_SENIOR_HH  \
# Auspraegung_Text Haushalte mit Senioren/-innen und Jüngeren
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       3.0
# 4                                                       NaN
# ...                                                     ...
# 14327260                                                NaN
# 14327261                                                NaN
# 14327262                                                NaN
# 14327263                                                NaN
# 14327264                                                NaN
#
# Merkmal                                        FAMTYP_KIND  \
# Auspraegung_Text Alleinerziehende Mütter alle Kinder ab 18
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 14327260                                               NaN
# 14327261                                               NaN
# 14327262                                               NaN
# 14327263                                               NaN
# 14327264                                               NaN
#
# Merkmal                         HHTYP_SENIOR_HH                FAMTYP_KIND  \
# Auspraegung_Text Haushalte ohne Senioren/-innen Ehepaare mind. 1 Kind < 18
# 0                                           NaN                        NaN
# 1                                           NaN                        NaN
# 2                                           NaN                        NaN
# 3                                           NaN                        NaN
# 4                                           NaN                        NaN
# ...                                         ...                        ...
# 14327260                                    3.0                        NaN
# 14327261                                    NaN                        NaN
# 14327262                                    NaN                        NaN
# 14327263                                    NaN                        NaN
# 14327264                                    NaN                        NaN
#
# Merkmal          FAMGROESS_KLASS                FAMTYP_KIND  \
# Auspraegung_Text      4 Personen Ehepaare alle Kinder ab 18
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                            NaN                        NaN
# ...                          ...                        ...
# 14327260                     NaN                        NaN
# 14327261                     NaN                        NaN
# 14327262                     NaN                        NaN
# 14327263                     NaN                        NaN
# 14327264                     NaN                        NaN
#
# Merkmal                              \
# Auspraegung_Text Ehepaare ohne Kind
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 14327260                        NaN
# 14327261                        NaN
# 14327262                        NaN
# 14327263                        3.0
# 14327264                        NaN
#
# Merkmal                                       HHTYP_SENIOR_HH  ...  \
# Auspraegung_Text Haushalte mit ausschließlich Senioren/-innen  ...
# 0                                                         NaN  ...
# 1                                                         NaN  ...
# 2                                                         NaN  ...
# 3                                                         NaN  ...
# 4                                                         NaN  ...
# ...                                                       ...  ...
# 14327260                                                  NaN  ...
# 14327261                                                  NaN  ...
# 14327262                                                  NaN  ...
# 14327263                                                  NaN  ...
# 14327264                                                  3.0  ...
#
# Merkmal                                 FAMTYP_KIND  \
# Auspraegung_Text Nichteheliche Lebensgem. ohne Kind
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 14327260                                        NaN
# 14327261                                        NaN
# 14327262                                        NaN
# 14327263                                        NaN
# 14327264                                        NaN
#
# Merkmal                                                      \
# Auspraegung_Text Nichteheliche Lebensgem. mind. 1 Kind < 18
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 14327260                                                NaN
# 14327261                                                NaN
# 14327262                                                NaN
# 14327263                                                NaN
# 14327264                                                NaN
#
# Merkmal                                                     \
# Auspraegung_Text Alleinerziehende Mütter mind. 1 Kind < 18
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 14327260                                               NaN
# 14327261                                               NaN
# 14327262                                               NaN
# 14327263                                               NaN
# 14327264                                               NaN
#
# Merkmal                                                    \
# Auspraegung_Text Alleinerziehende Väter alle Kinder ab 18
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 14327260                                              NaN
# 14327261                                              NaN
# 14327262                                              NaN
# 14327263                                              NaN
# 14327264                                              NaN
#
# Merkmal                                                    \
# Auspraegung_Text Alleinerziehende Väter mind. 1 Kind < 18
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 14327260                                              NaN
# 14327261                                              NaN
# 14327262                                              NaN
# 14327263                                              NaN
# 14327264                                              NaN
#
# Merkmal                                                            \
# Auspraegung_Text Eingetr. Lebenspartnerschaften mind. 1 Kind < 18
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ...                                                           ...
# 14327260                                                      NaN
# 14327261                                                      NaN
# 14327262                                                      NaN
# 14327263                                                      NaN
# 14327264                                                      NaN
#
# Merkmal              FAMGROESS_KLASS                              FAMTYP_KIND  \
# Auspraegung_Text 6 und mehr Personen Eingetr. Lebenspartnerschaften ohne Kind
# 0                                NaN                                      NaN
# 1                                NaN                                      NaN
# 2                                NaN                                      NaN
# 3                                NaN                                      NaN
# 4                                NaN                                      NaN
# ...                              ...                                      ...
# 14327260                         NaN                                      NaN
# 14327261                         NaN                                      NaN
# 14327262                         NaN                                      NaN
# 14327263                         NaN                                      NaN
# 14327264                         NaN                                      NaN
#
# Merkmal                                                      \
# Auspraegung_Text Nichteheliche Lebensgem. alle Kinder ab 18
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                                       NaN
# 4                                                       NaN
# ...                                                     ...
# 14327260                                                NaN
# 14327261                                                NaN
# 14327262                                                NaN
# 14327263                                                NaN
# 14327264                                                NaN
#
# Merkmal
# Auspraegung_Text Eingetr. Lebenspartnerschaften alle Kinder ab 18
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ...                                                           ...
# 14327260                                                      NaN
# 14327261                                                      NaN
# 14327262                                                      NaN
# 14327263                                                      NaN
# 14327264                                                      NaN
#
# [14327265 rows x 22 columns]

# %%
pivot_df2 = families.pivot(index='Gitter_ID_100m', columns=['Merkmal', 'Auspraegung_Text'], values='Anzahl')

# %%
pivot_df2
# Out:
# Merkmal                    INSGESAMT FAMGROESS_KLASS  \
# Auspraegung_Text Einheiten insgesamt      2 Personen
# Gitter_ID_100m
# 100mN26912E43412                 3.0             NaN
# 100mN26917E43411                 3.0             3.0
# 100mN26924E43412                 3.0             3.0
# 100mN26926E43410                 3.0             3.0
# 100mN26927E43410                 3.0             NaN
# ...                              ...             ...
# 100mN35475E42200                 7.0             7.0
# 100mN35475E42201                 8.0             7.0
# 100mN35476E42198                 7.0             7.0
# 100mN35476E42199                 4.0             3.0
# 100mN35476E42201                 4.0             3.0
#
# Merkmal                                     HHTYP_SENIOR_HH  \
# Auspraegung_Text Haushalte mit Senioren/-innen und Jüngeren
# Gitter_ID_100m
# 100mN26912E43412                                        NaN
# 100mN26917E43411                                        3.0
# 100mN26924E43412                                        NaN
# 100mN26926E43410                                        NaN
# 100mN26927E43410                                        NaN
# ...                                                     ...
# 100mN35475E42200                                        3.0
# 100mN35475E42201                                        NaN
# 100mN35476E42198                                        NaN
# 100mN35476E42199                                        NaN
# 100mN35476E42201                                        NaN
#
# Merkmal                                        FAMTYP_KIND  \
# Auspraegung_Text Alleinerziehende Mütter alle Kinder ab 18
# Gitter_ID_100m
# 100mN26912E43412                                       NaN
# 100mN26917E43411                                       NaN
# 100mN26924E43412                                       3.0
# 100mN26926E43410                                       NaN
# 100mN26927E43410                                       NaN
# ...                                                    ...
# 100mN35475E42200                                       NaN
# 100mN35475E42201                                       3.0
# 100mN35476E42198                                       NaN
# 100mN35476E42199                                       NaN
# 100mN35476E42201                                       NaN
#
# Merkmal                         HHTYP_SENIOR_HH                FAMTYP_KIND  \
# Auspraegung_Text Haushalte ohne Senioren/-innen Ehepaare mind. 1 Kind < 18
# Gitter_ID_100m
# 100mN26912E43412                            NaN                        NaN
# 100mN26917E43411                            NaN                        NaN
# 100mN26924E43412                            3.0                        NaN
# 100mN26926E43410                            NaN                        NaN
# 100mN26927E43410                            3.0                        NaN
# ...                                         ...                        ...
# 100mN35475E42200                            3.0                        NaN
# 100mN35475E42201                            5.0                        NaN
# 100mN35476E42198                            3.0                        NaN
# 100mN35476E42199                            3.0                        NaN
# 100mN35476E42201                            NaN                        NaN
#
# Merkmal          FAMGROESS_KLASS                FAMTYP_KIND  \
# Auspraegung_Text      4 Personen Ehepaare alle Kinder ab 18
# Gitter_ID_100m
# 100mN26912E43412             NaN                        NaN
# 100mN26917E43411             NaN                        NaN
# 100mN26924E43412             NaN                        NaN
# 100mN26926E43410             NaN                        NaN
# 100mN26927E43410             NaN                        NaN
# ...                          ...                        ...
# 100mN35475E42200             NaN                        NaN
# 100mN35475E42201             NaN                        NaN
# 100mN35476E42198             NaN                        NaN
# 100mN35476E42199             NaN                        NaN
# 100mN35476E42201             NaN                        NaN
#
# Merkmal                              \
# Auspraegung_Text Ehepaare ohne Kind
# Gitter_ID_100m
# 100mN26912E43412                NaN
# 100mN26917E43411                NaN
# 100mN26924E43412                NaN
# 100mN26926E43410                NaN
# 100mN26927E43410                NaN
# ...                             ...
# 100mN35475E42200                4.0
# 100mN35475E42201                5.0
# 100mN35476E42198                7.0
# 100mN35476E42199                NaN
# 100mN35476E42201                3.0
#
# Merkmal                                       HHTYP_SENIOR_HH  ...  \
# Auspraegung_Text Haushalte mit ausschließlich Senioren/-innen  ...
# Gitter_ID_100m                                                 ...
# 100mN26912E43412                                          NaN  ...
# 100mN26917E43411                                          NaN  ...
# 100mN26924E43412                                          NaN  ...
# 100mN26926E43410                                          NaN  ...
# 100mN26927E43410                                          NaN  ...
# ...                                                       ...  ...
# 100mN35475E42200                                          3.0  ...
# 100mN35475E42201                                          NaN  ...
# 100mN35476E42198                                          4.0  ...
# 100mN35476E42199                                          NaN  ...
# 100mN35476E42201                                          3.0  ...
#
# Merkmal                                 FAMTYP_KIND  \
# Auspraegung_Text Nichteheliche Lebensgem. ohne Kind
# Gitter_ID_100m
# 100mN26912E43412                                NaN
# 100mN26917E43411                                NaN
# 100mN26924E43412                                NaN
# 100mN26926E43410                                NaN
# 100mN26927E43410                                NaN
# ...                                             ...
# 100mN35475E42200                                3.0
# 100mN35475E42201                                NaN
# 100mN35476E42198                                NaN
# 100mN35476E42199                                NaN
# 100mN35476E42201                                NaN
#
# Merkmal                                                      \
# Auspraegung_Text Nichteheliche Lebensgem. mind. 1 Kind < 18
# Gitter_ID_100m
# 100mN26912E43412                                        NaN
# 100mN26917E43411                                        NaN
# 100mN26924E43412                                        NaN
# 100mN26926E43410                                        NaN
# 100mN26927E43410                                        NaN
# ...                                                     ...
# 100mN35475E42200                                        NaN
# 100mN35475E42201                                        NaN
# 100mN35476E42198                                        NaN
# 100mN35476E42199                                        NaN
# 100mN35476E42201                                        NaN
#
# Merkmal                                                     \
# Auspraegung_Text Alleinerziehende Mütter mind. 1 Kind < 18
# Gitter_ID_100m
# 100mN26912E43412                                       NaN
# 100mN26917E43411                                       NaN
# 100mN26924E43412                                       NaN
# 100mN26926E43410                                       NaN
# 100mN26927E43410                                       NaN
# ...                                                    ...
# 100mN35475E42200                                       NaN
# 100mN35475E42201                                       NaN
# 100mN35476E42198                                       NaN
# 100mN35476E42199                                       NaN
# 100mN35476E42201                                       NaN
#
# Merkmal                                                    \
# Auspraegung_Text Alleinerziehende Väter alle Kinder ab 18
# Gitter_ID_100m
# 100mN26912E43412                                      NaN
# 100mN26917E43411                                      NaN
# 100mN26924E43412                                      NaN
# 100mN26926E43410                                      NaN
# 100mN26927E43410                                      NaN
# ...                                                   ...
# 100mN35475E42200                                      NaN
# 100mN35475E42201                                      NaN
# 100mN35476E42198                                      NaN
# 100mN35476E42199                                      NaN
# 100mN35476E42201                                      NaN
#
# Merkmal                                                    \
# Auspraegung_Text Alleinerziehende Väter mind. 1 Kind < 18
# Gitter_ID_100m
# 100mN26912E43412                                      NaN
# 100mN26917E43411                                      NaN
# 100mN26924E43412                                      NaN
# 100mN26926E43410                                      NaN
# 100mN26927E43410                                      NaN
# ...                                                   ...
# 100mN35475E42200                                      NaN
# 100mN35475E42201                                      NaN
# 100mN35476E42198                                      NaN
# 100mN35476E42199                                      NaN
# 100mN35476E42201                                      NaN
#
# Merkmal                                                            \
# Auspraegung_Text Eingetr. Lebenspartnerschaften mind. 1 Kind < 18
# Gitter_ID_100m
# 100mN26912E43412                                              NaN
# 100mN26917E43411                                              NaN
# 100mN26924E43412                                              NaN
# 100mN26926E43410                                              NaN
# 100mN26927E43410                                              NaN
# ...                                                           ...
# 100mN35475E42200                                              NaN
# 100mN35475E42201                                              NaN
# 100mN35476E42198                                              NaN
# 100mN35476E42199                                              NaN
# 100mN35476E42201                                              NaN
#
# Merkmal              FAMGROESS_KLASS                              FAMTYP_KIND  \
# Auspraegung_Text 6 und mehr Personen Eingetr. Lebenspartnerschaften ohne Kind
# Gitter_ID_100m
# 100mN26912E43412                 NaN                                      NaN
# 100mN26917E43411                 NaN                                      NaN
# 100mN26924E43412                 NaN                                      NaN
# 100mN26926E43410                 NaN                                      NaN
# 100mN26927E43410                 NaN                                      NaN
# ...                              ...                                      ...
# 100mN35475E42200                 NaN                                      NaN
# 100mN35475E42201                 NaN                                      NaN
# 100mN35476E42198                 NaN                                      NaN
# 100mN35476E42199                 NaN                                      NaN
# 100mN35476E42201                 NaN                                      NaN
#
# Merkmal                                                      \
# Auspraegung_Text Nichteheliche Lebensgem. alle Kinder ab 18
# Gitter_ID_100m
# 100mN26912E43412                                        NaN
# 100mN26917E43411                                        NaN
# 100mN26924E43412                                        NaN
# 100mN26926E43410                                        NaN
# 100mN26927E43410                                        NaN
# ...                                                     ...
# 100mN35475E42200                                        NaN
# 100mN35475E42201                                        NaN
# 100mN35476E42198                                        NaN
# 100mN35476E42199                                        NaN
# 100mN35476E42201                                        NaN
#
# Merkmal
# Auspraegung_Text Eingetr. Lebenspartnerschaften alle Kinder ab 18
# Gitter_ID_100m
# 100mN26912E43412                                              NaN
# 100mN26917E43411                                              NaN
# 100mN26924E43412                                              NaN
# 100mN26926E43410                                              NaN
# 100mN26927E43410                                              NaN
# ...                                                           ...
# 100mN35475E42200                                              NaN
# 100mN35475E42201                                              NaN
# 100mN35476E42198                                              NaN
# 100mN35476E42199                                              NaN
# 100mN35476E42201                                              NaN
#
# [2420104 rows x 22 columns]

# %%
pivot_df2['INSGESAMT']['Einheiten insgesamt'].sum()
# Out:
# 22353129.0

# %%
pivot_df2['FAMGROESS_KLASS']
# Out:
# Auspraegung_Text  2 Personen  4 Personen  5 Personen  3 Personen  \
# Gitter_ID_100m
# 100mN26912E43412         NaN         NaN         NaN         NaN
# 100mN26917E43411         3.0         NaN         NaN         NaN
# 100mN26924E43412         3.0         NaN         NaN         NaN
# 100mN26926E43410         3.0         NaN         NaN         NaN
# 100mN26927E43410         NaN         NaN         NaN         NaN
# ...                      ...         ...         ...         ...
# 100mN35475E42200         7.0         NaN         NaN         NaN
# 100mN35475E42201         7.0         NaN         NaN         NaN
# 100mN35476E42198         7.0         NaN         NaN         NaN
# 100mN35476E42199         3.0         NaN         NaN         NaN
# 100mN35476E42201         3.0         NaN         NaN         NaN
#
# Auspraegung_Text  6 und mehr Personen
# Gitter_ID_100m
# 100mN26912E43412                  NaN
# 100mN26917E43411                  NaN
# 100mN26924E43412                  NaN
# 100mN26926E43410                  NaN
# 100mN26927E43410                  NaN
# ...                               ...
# 100mN35475E42200                  NaN
# 100mN35475E42201                  NaN
# 100mN35476E42198                  NaN
# 100mN35476E42199                  NaN
# 100mN35476E42201                  NaN
#
# [2420104 rows x 5 columns]

# %%
pivot_df2[['INSGESAMT','FAMGROESS_KLASS']]
# Out:
# Merkmal                    INSGESAMT FAMGROESS_KLASS                        \
# Auspraegung_Text Einheiten insgesamt      2 Personen 4 Personen 5 Personen
# Gitter_ID_100m
# 100mN26912E43412                 3.0             NaN        NaN        NaN
# 100mN26917E43411                 3.0             3.0        NaN        NaN
# 100mN26924E43412                 3.0             3.0        NaN        NaN
# 100mN26926E43410                 3.0             3.0        NaN        NaN
# 100mN26927E43410                 3.0             NaN        NaN        NaN
# ...                              ...             ...        ...        ...
# 100mN35475E42200                 7.0             7.0        NaN        NaN
# 100mN35475E42201                 8.0             7.0        NaN        NaN
# 100mN35476E42198                 7.0             7.0        NaN        NaN
# 100mN35476E42199                 4.0             3.0        NaN        NaN
# 100mN35476E42201                 4.0             3.0        NaN        NaN
#
# Merkmal
# Auspraegung_Text 3 Personen 6 und mehr Personen
# Gitter_ID_100m
# 100mN26912E43412        NaN                 NaN
# 100mN26917E43411        NaN                 NaN
# 100mN26924E43412        NaN                 NaN
# 100mN26926E43410        NaN                 NaN
# 100mN26927E43410        NaN                 NaN
# ...                     ...                 ...
# 100mN35475E42200        NaN                 NaN
# 100mN35475E42201        NaN                 NaN
# 100mN35476E42198        NaN                 NaN
# 100mN35476E42199        NaN                 NaN
# 100mN35476E42201        NaN                 NaN
#
# [2420104 rows x 6 columns]

# %%
# replace NaN with 0
pivot_df2.fillna(0, inplace=True)

# %%
pivot_df2['FAMSIZE_DC'] = pivot_df2['FAMGROESS_KLASS'].sum(axis=1) / pivot_df2['INSGESAMT']['Einheiten insgesamt']

# %%
pivot_df2[['INSGESAMT','FAMGROESS_KLASS','FAMSIZE_DC']]
# Out:
# Merkmal                    INSGESAMT FAMGROESS_KLASS                        \
# Auspraegung_Text Einheiten insgesamt      2 Personen 4 Personen 5 Personen
# Gitter_ID_100m
# 100mN26912E43412                 3.0             0.0        0.0        0.0
# 100mN26917E43411                 3.0             3.0        0.0        0.0
# 100mN26924E43412                 3.0             3.0        0.0        0.0
# 100mN26926E43410                 3.0             3.0        0.0        0.0
# 100mN26927E43410                 3.0             0.0        0.0        0.0
# ...                              ...             ...        ...        ...
# 100mN35475E42200                 7.0             7.0        0.0        0.0
# 100mN35475E42201                 8.0             7.0        0.0        0.0
# 100mN35476E42198                 7.0             7.0        0.0        0.0
# 100mN35476E42199                 4.0             3.0        0.0        0.0
# 100mN35476E42201                 4.0             3.0        0.0        0.0
#
# Merkmal                                         FAMSIZE_DC
# Auspraegung_Text 3 Personen 6 und mehr Personen
# Gitter_ID_100m
# 100mN26912E43412        0.0                 0.0      0.000
# 100mN26917E43411        0.0                 0.0      1.000
# 100mN26924E43412        0.0                 0.0      1.000
# 100mN26926E43410        0.0                 0.0      1.000
# 100mN26927E43410        0.0                 0.0      0.000
# ...                     ...                 ...        ...
# 100mN35475E42200        0.0                 0.0      1.000
# 100mN35475E42201        0.0                 0.0      0.875
# 100mN35476E42198        0.0                 0.0      1.000
# 100mN35476E42199        0.0                 0.0      0.750
# 100mN35476E42201        0.0                 0.0      0.750
#
# [2420104 rows x 7 columns]

# %%
pivot_df2['FAMGROESS_KLASS'].sum().sum()
# Out:
# 20752033.0

# %%
20752033.0/22353129.0
# Out:
# 0.9283726229110922

# %%
pivot_df2['HHTYP_SENIOR_HH']

# %%
# create histogram of FAMSIZE_DC with % of total on y axis

pivot_df2['FAMSIZE_DC'].hist(bins=10)
# Out:
# <Axes: >
