# %% [markdown]
# # Czech Census data
#
# This notebook explores data from CSU

# %%
from glob import glob
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np

# %%
ls /data/uscuni-restricted/Data_SLDB_2021/zsj_data/ZSJD_slouceneZSJD/sloucene
# Out:
# _prevodnik_zsjd_nadzsjd.xlsx
# _sloucene_zsj_dily.docx
# _ukazatele_slouceneZSJD.xlsx
# nadzsjd_Byty_2021.xlsx
# nadzsjd_Byty_druh_obdobi_vystavby_2021.xlsx
# nadzsjd_Byty_velikost_vybaveni_2021.xlsx
# nadzsjd_Byty_vytapeni_2021.xlsx
# nadzsjd_D_Domy_2021.xlsx
# nadzsjd_Domacnosti_2021.xlsx
# nadzsjd_ekonomicka_aktivita_pohlavi_2021.xlsx
# nadzsjd_nabozenstvi_pohlavi_2021.xlsx
# nadzsjd_pobyt_pohlavi_2021.xlsx
# nadzsjd_rodinny_stav_pohlavi_2021.xlsx
# nadzsjd_statni_obcanstvi_2021.xlsx
# nadzsjd_statni_obcanstvi_narodnost_2021.xlsx
# nadzsjd_vek_pohlavi_2021.xlsx
# nadzsjd_vzdelani_pohlavi_2021.xlsx
# nadzsjd_zamestnani_2021.xlsx
# nadzsjd_zamestnani_ek_cinnost_pohlavi_2021.xlsx
# nadzsjd_zamestnani_postaveni_vek_2021.xlsx

# %%
# zacinme 4. indexem a sheet 1
# u nadzsjd_D_Domy_2021 az 3., 
# u nadzsjd_Domacnosti_2021 az 7.


# nadzsjd_Byty_2021.xlsx / done
#nadzsjd_Byty_druh_obdobi_vystavby_2021.xlsx /done
#nadzsjd_Byty_velikost_vybaveni_2021.xlsx /done
#nadzsjd_Byty_vytapeni_2021.xlsx / done
#nadzsjd_D_Domy_2021.xlsx /done
#nadzsjd_Domacnosti_2021.xlsx / done
#nadzsjd_ekonomicka_aktivita_pohlavi_2021.xlsx / done
#nadzsjd_nabozenstvi_pohlavi_2021.xlsx /done
#nadzsjd_pobyt_pohlavi_2021.xlsx /done
#nadzsjd_rodinny_stav_pohlavi_2021.xlsx / done
#nadzsjd_statni_obcanstvi_2021.xlsx / done
#nadzsjd_statni_obcanstvi_narodnost_2021.xlsx / done
#nadzsjd_vek_pohlavi_2021.xlsx /done
#nadzsjd_vzdelani_pohlavi_2021.xlsx /done
#nadzsjd_zamestnani_2021.xlsx / done
#nadzsjd_zamestnani_ek_cinnost_pohlavi_2021.xlsx / done
#nadzsjd_zamestnani_postaveni_vek_2021.xlsx / done
‘‘‘

# %%
data = pd.read_excel('/data/uscuni-restricted/Data_SLDB_2021/zsj_data/ZSJD_slouceneZSJD/sloucene/nadzsjd_Domacnosti_2021.xlsx', 
                     sheet_name=1)
data.head(8)
# Out:
#   Hospodařící domácnosti v bytech podle počtu členů a typu domácnosti  \
# 0                 ÚDAJE ZA SLOUČENÉ ZSJ-DÍL (CIS 53)
# 1                             podle obvyklého pobytu
# 2  Hospodařící domácnosti v bytech podle počtu čl...
# 3                                   SLOUČENÉ ZSJ-DÍL
# 4                             podle obvyklého pobytu
# 5                                              NUTS2
# 6                                             NUTS_2
# 7                                               CZ01
#
#            Unnamed: 1 Unnamed: 2          Unnamed: 3  Unnamed: 4 Unnamed: 5  \
# 0                 NaN        NaN                 NaN         NaN        NaN
# 1                 NaN        NaN                 NaN         NaN        NaN
# 2                 NaN        NaN                 NaN         NaN        NaN
# 3                 NaN        NaN                 NaN         NaN        NaN
# 4                 NaN        NaN                 NaN         NaN        NaN
# ...

# %%
data.iloc[:,7:15].head(8)
# Out:
#                                           Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0                                                NaN        NaN        NaN
# 1                                                NaN        NaN        NaN
# 2                                                NaN        NaN        NaN
# 3                                                NaN        NaN        NaN
# 4                                                NaN        NaN        NaN
# 5  Název správního obvodu obce\ns rozšířenou půso...   Kód obce       Obec
# 6                                            naz_orp   kod_obec   naz_obec
# 7                                              Praha     554782      Praha
#
#          Unnamed: 10                                     Unnamed: 11  \
# 0                NaN                                             NaN
# 1                NaN                                             NaN
# 2                NaN                                             NaN
# ...

# %%
data.iloc[5, 0:13] = data.iloc[6, 0:13]

# %%
data.iloc[:,7:15].head(8)
# Out:
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12  \
# 0        NaN        NaN        NaN         NaN         NaN         NaN
# 1        NaN        NaN        NaN         NaN         NaN         NaN
# 2        NaN        NaN        NaN         NaN         NaN         NaN
# 3        NaN        NaN        NaN         NaN         NaN         NaN
# 4        NaN        NaN        NaN         NaN         NaN         NaN
# 5    naz_orp   kod_obec   naz_obec     kod_mco   nazev_mco     nadzsjd
# 6    naz_orp   kod_obec   naz_obec     kod_mco   nazev_mco     nadzsjd
# 7      Praha     554782      Praha      500054     Praha 1     1270600
#
#                               Unnamed: 13  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5  Hospodařící domácnosti v bytech celkem
# ...

# %%
data.columns = data.iloc[5]
data
# Out:
# 5                                                 NUTS_2       naz_oblast  \
# 0                     ÚDAJE ZA SLOUČENÉ ZSJ-DÍL (CIS 53)              NaN
# 1                                 podle obvyklého pobytu              NaN
# 2      Hospodařící domácnosti v bytech podle počtu čl...              NaN
# 3                                       SLOUČENÉ ZSJ-DÍL              NaN
# 4                                 podle obvyklého pobytu              NaN
# ...                                                  ...              ...
# 21059                                               CZ08  Moravskoslezsko
# 21060                                               CZ08  Moravskoslezsko
# 21061                                               CZ08  Moravskoslezsko
# 21062                                               CZ08  Moravskoslezsko
# 21063                                               CZ08  Moravskoslezsko
#
# 5     NUTS_3              naz_kraj kod_okres      naz_okres kod_orp  naz_orp  \
# ...

# %%
data.head(9)
# Out:
# 5                                             NUTS_2  naz_oblast  NUTS_3  \
# 0                 ÚDAJE ZA SLOUČENÉ ZSJ-DÍL (CIS 53)         NaN     NaN
# 1                             podle obvyklého pobytu         NaN     NaN
# 2  Hospodařící domácnosti v bytech podle počtu čl...         NaN     NaN
# 3                                   SLOUČENÉ ZSJ-DÍL         NaN     NaN
# 4                             podle obvyklého pobytu         NaN     NaN
# 5                                             NUTS_2  naz_oblast  NUTS_3
# 6                                             NUTS_2  naz_oblast  NUTS_3
# 7                                               CZ01       Praha   CZ010
# 8                                               CZ01       Praha   CZ010
#
# 5            naz_kraj  kod_okres  naz_okres  kod_orp  naz_orp  kod_obec  \
# 0                 NaN        NaN        NaN      NaN      NaN       NaN
# 1                 NaN        NaN        NaN      NaN      NaN       NaN
# ...

# %%
data = data.iloc[7:]
data.head(2)
# Out:
# 5 NUTS_2 naz_oblast NUTS_3            naz_kraj kod_okres naz_okres kod_orp  \
# 7   CZ01      Praha  CZ010  Hlavní město Praha     40924     Praha    1000
# 8   CZ01      Praha  CZ010  Hlavní město Praha     40924     Praha    1000
#
# 5 naz_orp kod_obec naz_obec  ...  \
# 7   Praha   554782    Praha  ...
# 8   Praha   554782    Praha  ...
#
# 5 Hospodařící domácnosti v bytech - typ HD: rodinné domácnosti tvořené 1 rodinou - úplné rodiny - manželské páry  \
# 7                                                  0
# 8                                                  0
#
# 5 Hospodařící domácnosti v bytech - typ HD: rodinné domácnosti tvořené 1 rodinou - úplné rodiny - manželské páry  - počet členů domácnosti: 2  \
# 7                                                  0
# 8                                                  0
#
# 5 Hospodařící domácnosti v bytech - typ HD: rodinné domácnosti tvořené 1 rodinou - úplné rodiny - manželské páry  - počet členů domácnosti: 3  \
# ...

# %%
data = data.iloc[:,12:]
data
# Out:
# 5       nadzsjd Hospodařící domácnosti v bytech celkem  \
# 7       1270600                                      0
# 8       1271590                                      0
# 9       3182130                                      0
# 10      3182640                                      0
# 11     50005401                                    559
# ...         ...                                    ...
# 21059  50029101                                     25
# 21060  50029102                                    268
# 21061  50029103                                    788
# 21062  56844901                                    226
# 21063  56844902                                     18
#
# 5     Hospodařící domácnosti v bytech - počet členů domácnosti: 1  \
# 7                                                      0
# 8                                                      0
# 9                                                      0
# 10                                                     0
# ...

# %%
data = data.rename(columns={
    'nadzsjd':'kod_nadzsj_d'
})

# %%
data.head(2)
# Out:
# 5 kod_nadzsj_d Hospodařící domácnosti v bytech celkem  \
# 7      1270600                                      0
# 8      1271590                                      0
#
# 5 Hospodařící domácnosti v bytech - počet členů domácnosti: 1  \
# 7                                                  0
# 8                                                  0
#
# 5 Hospodařící domácnosti v bytech - počet členů domácnosti: 2  \
# 7                                                  0
# 8                                                  0
#
# 5 Hospodařící domácnosti v bytech - počet členů domácnosti: 3  \
# 7                                                  0
# 8                                                  0
#
# 5 Hospodařící domácnosti v bytech - počet členů domácnosti: 4  \
# 7                                                  0
# 8                                                  0
#
# 5 Hospodařící domácnosti v bytech - počet členů domácnosti: 5 a více  \
# ...

# %%
data.to_csv('preprocessed_data/domacnosti.csv', index= False)

# %%
csv_files = glob.glob('/home/anna/people_places_germany/Notebooks/czechia/preprocessed_data/*')

# %%
all_columns = []

for file in csv_files:
    df = pd.read_csv(file)
    all_columns.extend(df.columns.tolist())
    
df_columns = pd.DataFrame(all_columns, columns=['Column Names'])
df_columns.to_csv('column_names.csv', index=False)

# %%
all_rows = []
for file in csv_files:
    file_name = os.path.basename(file)
    all_rows.append([file_name])
    df = pd.read_csv(file)
    columns = df.columns.tolist()
    for col in columns:
        all_rows.append([col])
df_columns = pd.DataFrame(all_rows, columns=['File/Column Name'])

df_columns.to_csv('column_names_with_files.csv', index=False)

# %%
import pandas as pd

# %%
ls
# Out:
# census_data_exploration.ipynb  census_zsj_d.ipynb           preprocessed_data/
# census_nadzsjd.ipynb           column_names.csv
# census_preprocessing.ipynb     column_names_with_files.csv

# %%
df = pd.read_csv('column_names_with_files.csv')

# %%
df['use'] = 0

# %%
df
# Out:
#                                       File/Column Name  use
# 0                                      vek_pohlavi.csv    0
# 1                                         kod_nadzsj_d    0
# 2                                  Obyvatelstvo celkem    0
# 3                           Obyvatelstvo celkem - muži    0
# 4                           Obyvatelstvo celkem - ženy    0
# ..                                                 ...  ...
# 817  Počet osob v bytech v rodinných domech  s mate...    0
# 818  Počet osob v bytech v bytových domech  s mater...    0
# 819                             Neobydlené byty celkem    0
# 820                 Neobydlené byty v rodinných domech    0
# 821                  Neobydlené byty v bytových domech    0
#
# [822 rows x 2 columns]

# %%
df['name'] = ''

# %%
df
# Out:
#                                       File/Column Name  use name
# 0                                      vek_pohlavi.csv    0
# 1                                         kod_nadzsj_d    0
# 2                                  Obyvatelstvo celkem    0
# 3                           Obyvatelstvo celkem - muži    0
# 4                           Obyvatelstvo celkem - ženy    0
# ..                                                 ...  ...  ...
# 817  Počet osob v bytech v rodinných domech  s mate...    0
# 818  Počet osob v bytech v bytových domech  s mater...    0
# 819                             Neobydlené byty celkem    0
# 820                 Neobydlené byty v rodinných domech    0
# 821                  Neobydlené byty v bytových domech    0
#
# [822 rows x 3 columns]

# %%
df.to_csv('col_names.csv', index=False)
