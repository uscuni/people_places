# %% [markdown]
# # Calculate variables

# %%
import pandas as pd

# %%
nvar = pd.read_csv("/data/uscuni-restricted/01_preprocessed_census/_column_names11.csv")

# %%
nvar = nvar.drop_duplicates()

# %%
nvar

# %% [markdown]
# total original variables

# %%
802 - 14

# %%
nvar.loc[nvar["use"] == 1.0]

# %% [markdown]
# selected variables

# %%
123 - 14

# %%
remain = pd.read_parquet(
    "/data/uscuni-restricted/04_spatial_census/_merged_census_2021.parquet"
)

# %%
remain

# %% [markdown]
# after aggregation

# %%
103 - 14
