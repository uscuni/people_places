# %%
import pandas as pd

# %%
path = "/Users/lisawinkler/Documents/PhD/Data/Germany_Census_2011/"

# %%
translation = pd.read_excel(path + 'Data_Format_Census.xlsx', sheet_name='Translations')

# %%
translation
# Out:
#                   Original              Translated
# 0                INSGESAMT                   TOTAL
# 1      Einheiten insgesamt                   Total
# 2              FAMTYP_KIND            FAMTYP_CHILD
# 3          FAMGROESS_KLASS                 FAMSIZE
# 4          HHTYP_SENIOR_HH            HHTYP_SENIOR
# ..                     ...                     ...
# 204              1 Wohnung             1 apartment
# 205            2 Wohnungen            2 apartments
# 206        3 - 6 Wohnungen        3 - 6 apartments
# 207       7 - 12 Wohnungen       7 - 12 apartments
# 208  13 und mehr Wohnungen  13 and more apartments
#
# [209 rows x 2 columns]

# %%
translation_dict = translation.set_index('Original')['Translated'].to_dict()

# %%
translation_dict
# Out:
# {'INSGESAMT': 'TOTAL',
#  'Einheiten insgesamt': 'Total',
#  'FAMTYP_KIND': 'FAMTYP_CHILD',
#  'FAMGROESS_KLASS': 'FAMSIZE',
#  'HHTYP_SENIOR_HH': 'HHTYP_SENIOR',
#  'Ehepaare ohne Kind': 'Married couples without children',
#  'Ehepaare, mind. 1 Kind < 18': 'Married couples, at least 1 child < 18',
#  'Ehepaare alle Kinder ≥ 18': 'Married couples all children ≥ 18',
#  'Eingetr. Lebenspartnerschaften ohne Kind': 'Registered Civil partnerships without children',
#  'Eingetr. Lebenspartnerschaften mind. 1 Kind < 18': 'Registered Civil partnerships with at least 1 child < 18',
#  'Eingetr. Lebenspartnerschaften alle Kinder ≥ 18': 'Registered Civil partnerships all children ≥ 18',
#  'Nichteheliche Lebensgem. ohne Kind': 'Non-marital cohabitation without child',
#  'Nichteheliche Lebensgem. mind. 1 Kind < 18': 'Non-marital cohabitation at least 1 child < 18',
#  'Nichteheliche Lebensgem. alle Kinder ≥ 18': 'Non-marital cohabitation all children ≥ 18',
#  'Alleinerziehende Väter mind. 1 Kind < 18': 'Single fathers with at least 1 child < 18',
#  'Alleinerziehende Väter alle Kinder ≥ 18': 'Single fathers all children ≥ 18',
#  'Alleinerziehende Mütter mind. 1 Kind < 18': 'Single mothers with at least 1 child < 18',
#  'Alleinerziehende Mütter alle Kinder ≥ 18': 'Single mothers all children ≥ 18',
#  '2 Personen': '2 people',
#  '3 Personen': '3 people',
#  '4 Personen': '4 people',
#  '5 Personen': '5 people',
#  '6 und mehr Personen': '6 or more people',
#  'Haushalte mit ausschließlich Senioren/-innen': 'Households with only senior citizens',
#  'Haushalte mit Senioren/-innen und Jüngeren': 'Households with seniors and younger people',
#  'Haushalte ohne Senioren/-innen': 'Households without seniors',
#  'HHTYP_FAM': 'HHTYP_FAM',
#  'HHTYP_LEB': 'HHTYP_LS',
#  'HHGROESS_KLASS': 'HHSIZE',
#  'Einpersonenhaushalte (Singlehaushalte)': 'Single-person households',
#  'Paare ohne Kind(er)': 'Couples without children',
#  'Paare mit Kind(ern)': 'Couples with children',
#  'Alleinerziehende Elternteile': 'Single parents',
#  'Mehrpersonenhaushalte ohne Kernfamilie': 'Multi-person households without nuclear family',
#  'Ehepaare': 'Married couples',
#  'Eingetr. Lebenspartnerschaften': 'Registered civil partnerships',
#  'Nichteheliche Lebensgemeinschaften': 'Non-marital cohabitation',
#  'Alleinerziehende Mütter': 'Single mothers',
#  'Alleinerziehende Väter': 'Single fathers',
#  '1 Person': '1 person',
#  'ALTER_10JG': 'AGE_10',
#  'ALTER_KURZ': 'AGE_5',
#  'FAMSTND_AUSF': 'FAMTYP_MAR',
#  'GEBURTLAND_GRP': 'POB_GRP',
#  'GESCHLECHT': 'GENDER',
#  'RELIGION_KURZ': 'RELIGION',
#  'STAATSANGE_GRP': 'NATIONALITY_GRP',
#  'STAATSANGE_HLND': 'NATIONALITY_CNTRY',
#  'STAATSANGE_KURZ': 'NATIONALITY',
#  'STAATZHL': 'NATIONALITY_NO',
#  'Unter 10': 'Under 10',
#  '10 - 19': '10 - 19',
#  '20 - 29': '20 - 29',
#  '30 - 39': '30 - 39',
#  '40 - 49': '40 - 49',
#  '50 - 59': '50 - 59',
#  '60 - 69': '60 - 69',
#  '70 - 79': '70 - 79',
#  '80 und älter': '80 and older',
#  'Unter 18': 'Under 18',
#  '18 - 29': '18 - 29',
#  '30 - 49': '30 - 49',
#  '50 - 64': '50 - 64',
#  '65 und älter': '65 and older',
#  'Ledig': 'Single',
#  'Verheiratet': 'Married',
#  'Verwitwet': 'Widowed',
#  'Geschieden': 'Divorced',
#  'Eingetr. Lebenspartnerschaft': 'Registered civil partnership',
#  'Eingetr. Lebensparter/-in verstorben': 'Registered civil partner deceased',
#  'Eingetr. Lebenspartnerschaft aufgehoben': 'Registered Civil partnership dissolved',
#  'Ohne Angabe': 'No information',
#  'Deutschland': 'Germany',
#  'EU27-Land': 'EU27 country',
#  'Sonstiges Europa': 'Other Europe',
#  'Sonstige Welt': 'Other world',
#  'Sonstige': 'Other',
#  'Männlich': 'Male',
#  'Weiblich': 'Female',
#  'Römisch-katholische Kirche (öffentlich-rechtlich)': 'Roman Catholic Church (public law)',
#  'Evangelische Kirche (öffentlich-rechtlich)': 'Evangelical Church (public law)',
#  'Sonstige, keine, ohne Angabe': 'Other, none, no information',
#  'Bosnien und Herzegowina': 'Bosnia and Herzegovina',
#  'Griechenland': 'Greece',
#  'Italien': 'Italy',
#  'Kasachstan': 'Kazakhstan',
#  'Kroatien': 'Croatia',
#  'Niederlande': 'Netherlands',
#  'Österreich': 'Austria',
#  'Polen': 'Poland',
#  'Rumänien': 'Romania',
#  'Russ. Föderation': 'Russian Federation',
#  'Türkei': 'Turkey',
#  'Ukraine': 'Ukraine',
#  'Ausland': 'Abroad',
#  'Eine Staatsangehörigkeit': 'One nationality',
#  'Mehrere, deutsch und ausländisch': 'Multiple, German and foreign',
#  'Mehrere, nur ausländisch': 'Multiple, only foreign',
#  'Nicht bekannt': 'Not known',
#  'NUTZUNG _DETAIL_HHGEN': 'USE_TYP',
#  'WOHNEIGENTUM': 'OWNERSHIP1',
#  'WOHNFLAECHE_10S': 'FLOOR_SPACE',
#  'RAUMANZAHL': 'ROOM_NO',
#  'GEBAEUDEART_SYS': 'BLDG_TYP1',
#  'BAUJAHR_MZ': 'BLDG_YR',
#  'EIGENTUM': 'OWNERSHIP2',
#  'GEBTYPBAUWEISE': 'BLDG_TYP2',
#  'GEBTYPGROESSE': 'BLDG_SIZE',
#  'HEIZTYP': 'HEAT_TYP',
#  'ZAHLWOHNGN_HHG': 'APT_NO',
#  'Von Eigentümer/-in bewohnt': 'Occupied by owner',
#  'Eigentum: mit aktuell geführtem Haushalt': 'Ownership: with currently managed household',
#  'Eigentum: ohne aktuell geführtem Haushalt': 'Ownership: without currently managed household',
#  'Zu Wohnzwecken vermietet': 'Rented for residential purposes',
#  'Vermietet: mit aktuell geführtem Haushalt': 'Rented: with currently managed household',
#  'Vermietet: ohne aktuell geführtem Haushalt': 'Rented: without currently managed household',
#  'Ferien- und Freizeitwohnung': 'Holiday and leisure apartment',
#  'Leer stehend': 'Vacant',
#  'Diplomaten-/Streitkräftewohnung': 'Diplomatic/armed forces apartment',
#  'Gewerbl. Nutzung': 'Commercial use',
#  'Privatperson/-en': 'Private person/s',
#  'Privatwirtschaftliche Unternehmen (jur. Personen)': 'Private companies (legal entities)',
#  'Öffentliche Unternehmen, Kirchen o.ä.': 'Public companies, churches, etc.',
#  'Wohnungsgenossenschaft': 'Housing cooperative',
#  'Trifft nicht zu (da keine Eigentumswohnung)': 'Does not apply (as it is not a owner-occupied apartment)',
#  'Unter 30': 'Under 30',
#  '80 - 89': '80 - 89',
#  '90 - 99': '90 - 99',
#  '100 - 109': '100 - 109',
#  '110 - 119': '110 - 119',
#  '120 - 129': '120 - 129',
#  '130 - 139': '130 - 139',
#  '140 - 149': '140 - 149',
#  '150 - 159': '150 - 159',
#  '160 -169': '160 -169',
#  '170 - 179': '170 - 179',
#  '180 und mehr': '180 and more',
#  't.n.z., gewerblich': 't.n.z., commercial',
#  '1 Raum': '1 room',
#  '2 Räume': '2 rooms',
#  '3 Räume': '3 rooms',
#  '4 Räume': '4 rooms',
#  '5 Räume': '5 rooms',
#  '6 Räume': '6 rooms',
#  '7 und mehr Räume': '7 and more rooms',
#  'Gebäude mit Wohnraum': 'Building with living space',
#  'Wohngebäude': 'Residential building',
#  'Wohngebäude (ohne Wohnheime)': 'Residential building (without Dormitories)',
#  'Wohnheim': 'Dormitory',
#  'Sonstiges Gebäude mit Wohnraum': 'Other building with living space',
#  'Vor 1919': 'Before 1919',
#  '1919 - 1948': '1919 - 1948',
#  '1949 - 1978': '1949 - 1978',
#  '1979 - 1986': '1979 - 1986',
#  '1987 - 1990': '1987 - 1990',
#  '1991 - 1995': '1991 - 1995',
#  '1996 - 2000': '1996 - 2000',
#  '2001 - 2004': '2001 - 2004',
#  '2005 - 2008': '2005 - 2008',
#  '2009 und später': '2009 and later',
#  'Gemeinschaft von Wohnungseigentümern/-innen': 'Community of homeowners',
#  'Privatperson/en': 'Private individual(s)',
#  'Kommune oder Kommunales Wohnungsunternehmen': 'Municipality or municipal housing company',
#  'Privatwirtschaftliches Wohnungsunternehmen': 'Private housing company',
#  'Anderes privatwirtschaftliches Unternehmen': 'Other private company',
#  'Bund oder Land': 'Federal or state government',
#  'Organisation ohne Erwerbszweck (z.B. Kirche)': 'Non-profit organization (e.g. church)',
#  'Freistehendes Haus': 'Detached house',
#  'Doppelhaus hälfte': 'Semi-detached house',
#  'Gereihtes Haus': 'Terraced house',
#  'Anderer Gebäudetyp': 'Other building type',
#  'Freistehendes Einfamilienhaus': 'Detached single-family house',
#  'Einfamilienhaus: Doppelhaushälfte': 'Single-family house: Semi-detached house',
#  'Einfamilienhaus: Reihenhaus': 'Single-family house: Terraced house',
#  'Freistehendes Zweifamilienhaus': 'Detached two-family house',
#  'Zweifamilienhaus: Doppelhaushälfte': 'Two-family house: Semi-detached house',
#  'Zweifamilienhaus: Reihenhaus': 'Two-family house: Terraced house',
#  'Mehrfamilienhaus: 3-6 Wohnungen': 'Multi-family house: 3-6 apartments',
#  'Mehrfamilienhaus: 7-12 Wohnungen': 'Multi-family house: 7-12 apartments',
#  'Mehrfamilienhaus: 13 und mehr Wohnungen': 'Multi-family house: 13 and more apartments',
#  'Fernheizung (Fernwärme)': 'District heating (district heating)',
#  'Etagenheizung': 'Floor heating',
#  'Blockheizung': 'Block heating',
#  'Zentralheizung': 'Central heating',
#  'Einzel-/Mehrraumöfen (auch Nachtspeicherheizung)': 'Single/multi-room heaters (also night storage heaters)',
#  'Keine Heizung im Gebäude oder in den Wohnungen': 'No heating in the building or in the apartments',
#  '1 Wohnung': '1 apartment',
#  '2 Wohnungen': '2 apartments',
#  '3 - 6 Wohnungen': '3 - 6 apartments',
#  '7 - 12 Wohnungen': '7 - 12 apartments',
#  '13 und mehr Wohnungen': '13 and more apartments'}

# %%
households = pd.read_csv(path + 'csv_Haushalte_100m_Gitter/Haushalte100m.csv', delimiter=',', encoding="cp1252")

# %%
households
# Out:
#             Gitter_ID_100m              Gitter_ID_100m_neu         Merkmal  \
# 0         100mN26891E43370  CRS3035RES100mN2689100E4337000       INSGESAMT
# 1         100mN26912E43412  CRS3035RES100mN2691200E4341200       INSGESAMT
# 2         100mN26912E43412  CRS3035RES100mN2691200E4341200       HHTYP_LEB
# 3         100mN26917E43411  CRS3035RES100mN2691700E4341100       INSGESAMT
# 4         100mN26917E43411  CRS3035RES100mN2691700E4341100  HHGROESS_KLASS
# ...                    ...                             ...             ...
# 18806021  100mN35476E42201  CRS3035RES100mN3547600E4220100  HHGROESS_KLASS
# 18806022  100mN35476E42201  CRS3035RES100mN3547600E4220100       HHTYP_FAM
# 18806023  100mN35476E42201  CRS3035RES100mN3547600E4220100       HHTYP_FAM
# 18806024  100mN35476E42201  CRS3035RES100mN3547600E4220100       HHTYP_LEB
# 18806025  100mN35476E42201  CRS3035RES100mN3547600E4220100       HHTYP_LEB
#
#           Auspraegung_Code                        Auspraegung_Text  Anzahl  \
# 0                        0                     Einheiten insgesamt       3
# 1                        0                     Einheiten insgesamt       3
# 2                        2                                Ehepaare       3
# 3                        0                     Einheiten insgesamt       5
# 4                        1                                1 Person       3
# ...                    ...                                     ...     ...
# 18806021                 2                              2 Personen       3
# 18806022                 1  Einpersonenhaushalte (Singlehaushalte)       3
# 18806023                 2                     Paare ohne Kind(er)       3
# 18806024                 1  Einpersonenhaushalte (Singlehaushalte)       3
# 18806025                 2                                Ehepaare       4
#
#           Anzahl_q
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 18806021         0
# 18806022         0
# 18806023         0
# 18806024         0
# 18806025         0
#
# [18806026 rows x 7 columns]

# %%
pivot_df = households.pivot(index='Gitter_ID_100m', columns=['Merkmal', 'Auspraegung_Text'], values='Anzahl')

# %%
pivot_df
# Out:
# Merkmal                    INSGESAMT HHTYP_LEB HHGROESS_KLASS             \
# Auspraegung_Text Einheiten insgesamt  Ehepaare       1 Person 2 Personen
# Gitter_ID_100m
# 100mN26891E43370                 3.0       NaN            NaN        NaN
# 100mN26912E43412                 3.0       3.0            NaN        NaN
# 100mN26917E43411                 5.0       3.0            3.0        3.0
# 100mN26923E43411                 4.0       NaN            4.0        NaN
# 100mN26924E43412                 3.0       NaN            NaN        3.0
# ...                              ...       ...            ...        ...
# 100mN35475E42201                17.0       5.0            9.0        7.0
# 100mN35476E42198                20.0       7.0           13.0        7.0
# 100mN35476E42199                16.0       3.0           10.0        3.0
# 100mN35476E42200                 3.0       NaN            NaN        NaN
# 100mN35476E42201                 6.0       4.0            3.0        3.0
#
# Merkmal                                       HHTYP_FAM                      \
# Auspraegung_Text Einpersonenhaushalte (Singlehaushalte) Paare ohne Kind(er)
# Gitter_ID_100m
# 100mN26891E43370                                    NaN                 NaN
# 100mN26912E43412                                    NaN                 NaN
# 100mN26917E43411                                    3.0                 3.0
# 100mN26923E43411                                    4.0                 NaN
# 100mN26924E43412                                    NaN                 NaN
# ...                                                 ...                 ...
# 100mN35475E42201                                    9.0                 5.0
# 100mN35476E42198                                   13.0                 7.0
# 100mN35476E42199                                   10.0                 3.0
# 100mN35476E42200                                    NaN                 NaN
# 100mN35476E42201                                    3.0                 3.0
#
# Merkmal                                       HHTYP_LEB  \
# Auspraegung_Text Einpersonenhaushalte (Singlehaushalte)
# Gitter_ID_100m
# 100mN26891E43370                                    NaN
# 100mN26912E43412                                    NaN
# 100mN26917E43411                                    3.0
# 100mN26923E43411                                    4.0
# 100mN26924E43412                                    NaN
# ...                                                 ...
# 100mN35475E42201                                    9.0
# 100mN35476E42198                                   13.0
# 100mN35476E42199                                   10.0
# 100mN35476E42200                                    NaN
# 100mN35476E42201                                    3.0
#
# Merkmal                             HHTYP_FAM               HHTYP_LEB  \
# Auspraegung_Text Alleinerziehende Elternteile Alleinerziehende Mütter
# Gitter_ID_100m
# 100mN26891E43370                          NaN                     NaN
# 100mN26912E43412                          NaN                     NaN
# 100mN26917E43411                          NaN                     NaN
# 100mN26923E43411                          NaN                     NaN
# 100mN26924E43412                          3.0                     3.0
# ...                                       ...                     ...
# 100mN35475E42201                          3.0                     3.0
# 100mN35476E42198                          NaN                     NaN
# 100mN35476E42199                          NaN                     NaN
# 100mN35476E42200                          NaN                     NaN
# 100mN35476E42201                          NaN                     NaN
#
# Merkmal                    HHTYP_FAM HHGROESS_KLASS                        \
# Auspraegung_Text Paare mit Kind(ern)     4 Personen 5 Personen 3 Personen
# Gitter_ID_100m
# 100mN26891E43370                 NaN            NaN        NaN        NaN
# 100mN26912E43412                 NaN            NaN        NaN        NaN
# 100mN26917E43411                 NaN            NaN        NaN        NaN
# 100mN26923E43411                 NaN            NaN        NaN        NaN
# 100mN26924E43412                 NaN            NaN        NaN        NaN
# ...                              ...            ...        ...        ...
# 100mN35475E42201                 NaN            NaN        NaN        NaN
# 100mN35476E42198                 NaN            NaN        NaN        NaN
# 100mN35476E42199                 NaN            NaN        3.0        NaN
# 100mN35476E42200                 NaN            NaN        NaN        NaN
# 100mN35476E42201                 NaN            NaN        NaN        NaN
#
# Merkmal                                       HHTYP_FAM  \
# Auspraegung_Text Mehrpersonenhaushalte ohne Kernfamilie
# Gitter_ID_100m
# 100mN26891E43370                                    NaN
# 100mN26912E43412                                    NaN
# 100mN26917E43411                                    NaN
# 100mN26923E43411                                    NaN
# 100mN26924E43412                                    NaN
# ...                                                 ...
# 100mN35475E42201                                    NaN
# 100mN35476E42198                                    NaN
# 100mN35476E42199                                    3.0
# 100mN35476E42200                                    NaN
# 100mN35476E42201                                    NaN
#
# Merkmal                                       HHTYP_LEB  \
# Auspraegung_Text Mehrpersonenhaushalte ohne Kernfamilie
# Gitter_ID_100m
# 100mN26891E43370                                    NaN
# 100mN26912E43412                                    NaN
# 100mN26917E43411                                    NaN
# 100mN26923E43411                                    NaN
# 100mN26924E43412                                    NaN
# ...                                                 ...
# 100mN35475E42201                                    NaN
# 100mN35476E42198                                    NaN
# 100mN35476E42199                                    3.0
# 100mN35476E42200                                    NaN
# 100mN35476E42201                                    NaN
#
# Merkmal                                                                     \
# Auspraegung_Text Nichteheliche Lebensgemeinschaften Alleinerziehende Väter
# Gitter_ID_100m
# 100mN26891E43370                                NaN                    NaN
# 100mN26912E43412                                NaN                    NaN
# 100mN26917E43411                                NaN                    NaN
# 100mN26923E43411                                NaN                    NaN
# 100mN26924E43412                                NaN                    NaN
# ...                                             ...                    ...
# 100mN35475E42201                                NaN                    NaN
# 100mN35476E42198                                NaN                    NaN
# 100mN35476E42199                                NaN                    NaN
# 100mN35476E42200                                NaN                    NaN
# 100mN35476E42201                                NaN                    NaN
#
# Merkmal               HHGROESS_KLASS                      HHTYP_LEB
# Auspraegung_Text 6 und mehr Personen Eingetr. Lebenspartnerschaften
# Gitter_ID_100m
# 100mN26891E43370                 NaN                            NaN
# 100mN26912E43412                 NaN                            NaN
# 100mN26917E43411                 NaN                            NaN
# 100mN26923E43411                 NaN                            NaN
# 100mN26924E43412                 NaN                            NaN
# ...                              ...                            ...
# 100mN35475E42201                 NaN                            NaN
# 100mN35476E42198                 NaN                            NaN
# 100mN35476E42199                 NaN                            NaN
# 100mN35476E42200                 NaN                            NaN
# 100mN35476E42201                 NaN                            NaN
#
# [2665595 rows x 19 columns]

# %% [markdown]
# 0 and missing information is different. exclude NaNs from calculations. treat them in the formula e.g. 0 replacement (only if nans mean 0), or exclude them (mask isna)

# %% [markdown]
# read documentation on what nan means

# %%
pivot_df = pivot_df.rename(columns=translation_dict)

# %%
pivot_df
# Out:
# Merkmal          TOTAL        HHTYP_LS   HHSIZE           \
# Auspraegung_Text Total Married couples 1 person 2 people
# Gitter_ID_100m
# 100mN26891E43370   3.0             NaN      NaN      NaN
# 100mN26912E43412   3.0             3.0      NaN      NaN
# 100mN26917E43411   5.0             3.0      3.0      3.0
# 100mN26923E43411   4.0             NaN      4.0      NaN
# 100mN26924E43412   3.0             NaN      NaN      3.0
# ...                ...             ...      ...      ...
# 100mN35475E42201  17.0             5.0      9.0      7.0
# 100mN35476E42198  20.0             7.0     13.0      7.0
# 100mN35476E42199  16.0             3.0     10.0      3.0
# 100mN35476E42200   3.0             NaN      NaN      NaN
# 100mN35476E42201   6.0             4.0      3.0      3.0
#
# Merkmal                         HHTYP_FAM                           \
# Auspraegung_Text Single-person households Couples without children
# Gitter_ID_100m
# 100mN26891E43370                      NaN                      NaN
# 100mN26912E43412                      NaN                      NaN
# 100mN26917E43411                      3.0                      3.0
# 100mN26923E43411                      4.0                      NaN
# 100mN26924E43412                      NaN                      NaN
# ...                                   ...                      ...
# 100mN35475E42201                      9.0                      5.0
# 100mN35476E42198                     13.0                      7.0
# 100mN35476E42199                     10.0                      3.0
# 100mN35476E42200                      NaN                      NaN
# 100mN35476E42201                      3.0                      3.0
#
# Merkmal                          HHTYP_LS      HHTYP_FAM       HHTYP_LS  \
# Auspraegung_Text Single-person households Single parents Single mothers
# Gitter_ID_100m
# 100mN26891E43370                      NaN            NaN            NaN
# 100mN26912E43412                      NaN            NaN            NaN
# 100mN26917E43411                      3.0            NaN            NaN
# 100mN26923E43411                      4.0            NaN            NaN
# 100mN26924E43412                      NaN            3.0            3.0
# ...                                   ...            ...            ...
# 100mN35475E42201                      9.0            3.0            3.0
# 100mN35476E42198                     13.0            NaN            NaN
# 100mN35476E42199                     10.0            NaN            NaN
# 100mN35476E42200                      NaN            NaN            NaN
# 100mN35476E42201                      3.0            NaN            NaN
#
# Merkmal                      HHTYP_FAM   HHSIZE                    \
# Auspraegung_Text Couples with children 4 people 5 people 3 people
# Gitter_ID_100m
# 100mN26891E43370                   NaN      NaN      NaN      NaN
# 100mN26912E43412                   NaN      NaN      NaN      NaN
# 100mN26917E43411                   NaN      NaN      NaN      NaN
# 100mN26923E43411                   NaN      NaN      NaN      NaN
# 100mN26924E43412                   NaN      NaN      NaN      NaN
# ...                                ...      ...      ...      ...
# 100mN35475E42201                   NaN      NaN      NaN      NaN
# 100mN35476E42198                   NaN      NaN      NaN      NaN
# 100mN35476E42199                   NaN      NaN      3.0      NaN
# 100mN35476E42200                   NaN      NaN      NaN      NaN
# 100mN35476E42201                   NaN      NaN      NaN      NaN
#
# Merkmal                                               HHTYP_FAM  \
# Auspraegung_Text Multi-person households without nuclear family
# Gitter_ID_100m
# 100mN26891E43370                                            NaN
# 100mN26912E43412                                            NaN
# 100mN26917E43411                                            NaN
# 100mN26923E43411                                            NaN
# 100mN26924E43412                                            NaN
# ...                                                         ...
# 100mN35475E42201                                            NaN
# 100mN35476E42198                                            NaN
# 100mN35476E42199                                            3.0
# 100mN35476E42200                                            NaN
# 100mN35476E42201                                            NaN
#
# Merkmal                                                HHTYP_LS  \
# Auspraegung_Text Multi-person households without nuclear family
# Gitter_ID_100m
# 100mN26891E43370                                            NaN
# 100mN26912E43412                                            NaN
# 100mN26917E43411                                            NaN
# 100mN26923E43411                                            NaN
# 100mN26924E43412                                            NaN
# ...                                                         ...
# 100mN35475E42201                                            NaN
# 100mN35476E42198                                            NaN
# 100mN35476E42199                                            3.0
# 100mN35476E42200                                            NaN
# 100mN35476E42201                                            NaN
#
# Merkmal                                                            HHSIZE  \
# Auspraegung_Text Non-marital cohabitation Single fathers 6 or more people
# Gitter_ID_100m
# 100mN26891E43370                      NaN            NaN              NaN
# 100mN26912E43412                      NaN            NaN              NaN
# 100mN26917E43411                      NaN            NaN              NaN
# 100mN26923E43411                      NaN            NaN              NaN
# 100mN26924E43412                      NaN            NaN              NaN
# ...                                   ...            ...              ...
# 100mN35475E42201                      NaN            NaN              NaN
# 100mN35476E42198                      NaN            NaN              NaN
# 100mN35476E42199                      NaN            NaN              NaN
# 100mN35476E42200                      NaN            NaN              NaN
# 100mN35476E42201                      NaN            NaN              NaN
#
# Merkmal                               HHTYP_LS
# Auspraegung_Text Registered civil partnerships
# Gitter_ID_100m
# 100mN26891E43370                           NaN
# 100mN26912E43412                           NaN
# 100mN26917E43411                           NaN
# 100mN26923E43411                           NaN
# 100mN26924E43412                           NaN
# ...                                        ...
# 100mN35475E42201                           NaN
# 100mN35476E42198                           NaN
# 100mN35476E42199                           NaN
# 100mN35476E42200                           NaN
# 100mN35476E42201                           NaN
#
# [2665595 rows x 19 columns]

# %%
pivot_df['TOTAL']['Total'].sum()
# Out:
# 37343591.0

# %%
pivot_df['HHSIZE_DC'] = pivot_df['HHSIZE'].sum(axis=1) / pivot_df['TOTAL']['Total']

# %%
pivot_df['HHSIZE_DC'].hist(bins=10)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming pivot_df['HHSIZE_DC'] is a pandas Series
data = pivot_df['HHSIZE_DC']

# Calculate the histogram (bin counts) and bin edges
counts, bins = np.histogram(data)

# Normalize the counts to get percentage
counts = counts / counts.sum() * 100

# Create the histogram using plt.hist, using the bins from np.histogram
plt.hist(bins[:-1], bins, weights=counts)

plt.xlabel('HHSIZE_DC')
plt.ylabel('%')
plt.title('Histogram of HHSIZE_DC')

plt.show()

# %%
pivot_df.to_csv(path + 'Households100m_pivot.csv', sep=',', encoding="cp1252")

# %%
pivot_df['HHTYP_LS'].sum().sum()
# Out:
# 35302273.0

# %%
pivot_df['HHSIZE'].sum().sum()
# Out:
# 35040804.0

# %%
pivot_df['HHTYP_FAM'].sum().sum()
# Out:
# 35743161.0
